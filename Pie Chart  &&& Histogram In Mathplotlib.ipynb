# %%
Gender = ['Male','Female']

# %%
Population = [140,40]

# %%
import matplotlib.pyplot as plt

# %%
plt.pie(Population,labels = Gender,autopct='',explode = [0,0.1])
plt.title('pie Chart')
plt.show()

# %%
import pandas as pd
ser1 = pd.Series([140,60],index =['Male','Female'])

# %% [raw]
# ser1

# %%
ser1
# Out:
# Male      140
# Female     60
# dtype: int64

# %%
ser1.values
# Out:
# array([140,  60], dtype=int64)

# %%
plt.pie(ser1.values,labels = ser1.index)
plt.show()

# %%
import seaborn
import matplotlib

# %%
from matplotlib import pyplot

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
Mark1 = np.random.randint(1,101,20)

# %%
Mark1
# Out:
# array([ 30,  55,  32,  81,  66,   3,  11,  14,   4,  15,  99,  18, 100,
#         84,   9,  90,  92,  94,  10,   9])

# %%
min_mark = Mark1.min()
max_mark = Mark1.max()
print(min_mark,max_mark)
# Out:
# 3 100
