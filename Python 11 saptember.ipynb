# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# #### pie

# %% [markdown]
# - A pie chart in Python is a circular graph that divides a categorical dataset into slices, where each slice's size corresponds to the proportion or percentage of a specific category within the whole dataset.

# %%
plt.figure(figsize-(6,4))
df['smoker'].value_counts().plot(kind='pie',autopct='%0.3f%%')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 plt.figure(figsize-(6,4))
#       2 df['smoker'].value_counts().plot(kind='pie',autopct='%0.3f%%')
#       3 plt.show()
#
# NameError: name 'figsize' is not defined

# %%
################################################

# %% [markdown]
# ### Numerical

# %% [markdown]
# - KDE
# - Boxplot
# - Boxnplot
# - Violin plot
# - distplot
# - Histplot

# %% [markdown]
# ### KDE(Kernel Density Estimation)

# %% [markdown]
# KDE represents the data using a continuous probability density curve in one or more dimensions.

# %%
plt.figure(figsize=(5,3))
df['total_bill'].plot(kind='kde',color='g')
plt.grid()
plt.xlabel('Total bill ($)')
plt.show()

# %% [markdown]
# ### Outliers

# %%
2,2,3,5,100,4

# %% [markdown]
# ### kdeplot

# %%
#kdeplot
plt.figure(figsize=(5,3))
sns.kdeplot(data= df,x = 'total_bill',fill= True)
plt.show()

# %%
#kdeplot
plt.figure(figsize=(5,3))
sns.kdeplot(data= df,y = 'total_bill',fill= True)
plt.show()

# %% [markdown]
# ### Boxplot3

# %% [markdown]
# - Box plots provide a quick visual summary of the variability of values in a dataset.
# - They show the median, upper and lower quartiles, minimum and maximum values, and any outliers in the dataset.
# - Outliers can reveal mistakes or unusual occurrences in data.

# %%
plt.boxplot(df['total_bill'])
plt.show()

# %%
plt.boxplot(df['tip'])
plt.show()

# %% [markdown]
# ### sns

# %%
sns.boxplot(df['total_bill'])
plt.show()

# %%
sns.boxplot(data= df, y = 'size')
plt.show()

# %%
sns.boxplot(df['tip'])
plt.show()

# %%
sns.boxplot(data= df)
plt.show()

# %% [markdown]
# ### boxenplot

# %% [markdown]
# - Boxenplots are an advancement of boxplots, designed to visualize distributions more accurately.

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.boxenplot(data= df)
plt.show()

# %%
sns.boxenplot(df['tip'])
plt.show()

# %%
sns.boxenplot(data= df, y = 'size')
plt.show()

# %%
sns.boxenplot(data= df, x = 'size')
plt.show()

# %% [markdown]
# ### violin plot
# - is a hybrid of a box plot and a kernel density plot, which shows peaks in the data. It is used to visualize the distribution of numerical data.
#
# - violinplot=kde+boxplot

# %%
sns.violinplot(data =df, y ='size')
plt.grid()
plt .show()

# %% [markdown]
# histplot: The histplot function is primarily focused on creating histograms. While it can include a KDE overlay, its primary purpose is to display the frequency distribution of data in histogram form

# %%
plt.hist(df['tip'],edgecolor='k')
plt.xlabel('Tip ($)')
plt.ylabel('value counts of tips')
plt.show()

# %%
plt.hist(df['tip'],edgecolor='k',color='g',bins=50)
plt.xlabel('Tip ($)')
plt.ylabel('value counts of tips')
plt.show()

# %%
plt.hist(df['tip'],edgecolor='r',color='c',bins=50)
plt.xlabel('Tip ($)')
plt.ylabel('value counts of tips')
plt.show()

# %% [markdown]
# distplot: The distplot function was designed to create combined histograms and kernel density plots. It allowed you to visualize the distribution of a dataset using both histogram bars and a smoothed KDE line.

# %% [markdown]
# ### Numerical Numerical
# scatterplot
# implot
# regplot
# pairplot
# jointplot
# heatmap
# line

# %% [markdown]
# ### Scatterplot

# %%
in python you can create

# %%
plt.scatter(df['total_bill'],df['tip'])
plt.xlabel('Total_bill($)')
plt.ylabel('tip($)')
plt.title('Relationship  between total_bill$ tip')
plt.show()

# %%
plt.scatter(df['total_bill'],df['tip'],edgecolor='r')
plt.xlabel('Total_bill($)')
plt.ylabel('tip($)')
plt.title('Relationship  between total_bill$ tip')
plt.show()

# %%
plt.scatter(df['total_bill'],df['tip'],edgecolor ='r',color='g')
plt.xlabel('Total_bill($)')
plt.ylabel('tip($)')
plt.title('Relationship  between total_bill$ tip')

plt.axhline(2,color ='black',ls= '--')
plt.axhline(4,c ='k',ls= '--')
plt.axhline(10,c ='r',ls= '--')
plt.axhline(20,c ='r',ls= '--')
plt.show()
